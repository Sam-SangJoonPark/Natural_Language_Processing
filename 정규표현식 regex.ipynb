# %% [markdown]
# # https://wikidocs.net/4308
#
# - 이거 정독했는데, 진짜 잘 정리되어있음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 위 사이트에 나온 내용을 그대로 캡쳐한 것임. - 이것 정독했고, pdf 내용 :

# %% [markdown]
# # pdf는 좀 어려워서 요점만 정리하면
# - 컴파일 하는건 highly recommended함. 왜? 복잡해질수록 CPU 많이 줄임
# - regular expression = regex고, re는 이걸 지원하는 파이썬 모듈.
# - 정규식은 파이썬의 것 x 원래 있던 것이고, 고급 기술임
# - 나머진 좀 복잡한 메소드들 시범보이는. 일단 기본만 알기엔 저 사이트가 충분

# %%
regex = re.compile('\s+') # 컴파일 한다는 것은 이러한 패턴을 정규식 형태로? 저장한다는 의미같음

# %%
# 아까 저장한 text라는 문자열
text
# Out:
# 'Dave dave@google.com\nSteve steve@gmail.com\nRob rob@gmail.com\nRyan ryan@yahoo.com\n'

# %%
regex.split(text)
# Out:
# ['Dave',
#  'dave@google.com',
#  'Steve',
#  'steve@gmail.com',
#  'Rob',
#  'rob@gmail.com',
#  'Ryan',
#  'ryan@yahoo.com',
#  '']

# %%
regex.findall(text)
# Out:
# [' ', '\n', ' ', '\n', ' ', '\n', ' ', '\n']

# %%
regex
# Out:
# re.compile(r'\s+', re.UNICODE)

# %%
text
# Out:
# 'Dave dave@google.com\nSteve steve@gmail.com\nRob rob@gmail.com\nRyan ryan@yahoo.com\n'

# %%
m = regex.search(text)

# %%
text[m.start():m.end()]
# Out:
# ' '

# %%
print(regex.match(text))
# Out:
# None
